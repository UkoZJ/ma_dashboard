# %%
import numpy as np
import xarray as xr

import xdggs

xr.set_options(keep_attrs=True, display_expand_attrs=False, display_expand_indexes=True)

# %%
ds = xr.open_dataset("data/h3_example.nc")
ds
# Out:
# <xarray.Dataset> Size: 124MB
# Dimensions:  (time: 2920, cell: 5305)
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#   * cell     (cell) int64 42kB 590733444024107007 ... 590995677547331583
# Data variables:
#     air      (time, cell) float64 124MB ...
# Attributes: (5)

# %%
ds_idx = ds.pipe(xdggs.decode)
ds_idx
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ds_idx = ds.pipe(xdggs.H3Index)
#       2 ds_idx
#
# File ~/Dev/ma_dashboard/.envs/ma_dashboard_env/lib/python3.10/site-packages/xarray/core/common.py:832, in DataWithCoords.pipe(self, func, *args, **kwargs)
#     830     return func(*args, **kwargs)
#     831 else:
# --> 832     return func(self, *args, **kwargs)
#
# TypeError: H3Index.__init__() missing 2 required positional arguments: 'dim' and 'resolution'

# %%
ds_idx.dggs.sel_latlon(np.array([37.0, 37.5]), np.array([299.3, 299.5]))

# %%
ds2 = ds_idx.dggs.assign_latlon_coords()
ds2

# %%
result = ds_idx.dggs.sel_latlon(ds2.latitude.data, ds2.longitude.data)
result

# %%
xr.testing.assert_equal(result, ds)
